# %% [markdown]
# ### 普通线性回归

# %%
import numpy as np
import pandas as pd 
from sklearn.linear_model import LinearRegression
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#模型开始训练
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7     V8     V9  ...  \
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360 -0.436 -2.114  ...
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  0.332 -2.114  ...
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  0.396 -2.114  ...
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  0.403 -2.114  ...
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  0.314 -2.114  ...
#
#      V28    V29    V30    V31    V32    V33    V34    V35    V36    V37
# 0 -0.450  0.136  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.671 -0.128  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.287 -0.009  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  1.298  0.015  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  1.289  0.183  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# ...

# %% [markdown]
# ### Z_score归一化

# %% [markdown]
# #### Z_score不带截距

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')


#对数据进行归一化
standard = StandardScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)


#模型开始训练
model = LinearRegression()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear_Z_Score_No_intercept_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Z_Score带截距

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')


#对数据进行归一化
standard = StandardScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)


#模型开始训练
model = LinearRegression(fit_intercept=True)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear_Z_Score_with_intercept_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# ### 最大最小值归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')


#对数据进行归一化
standard = MinMaxScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)


#模型开始训练
model = LinearRegression(fit_intercept=True)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear_MinMaxScaler_t_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# ### 展示算法

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')


#对数据进行归一化
standard = MinMaxScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)


#模型开始训练
model = LinearRegression(fit_intercept=True)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('AAAAAAAAA.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7     V8     V9  ...  \
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360 -0.436 -2.114  ...
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  0.332 -2.114  ...
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  0.396 -2.114  ...
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  0.403 -2.114  ...
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  0.314 -2.114  ...
#
#      V28    V29    V30    V31    V32    V33    V34    V35    V36    V37
# 0 -0.450  0.136  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.671 -0.128  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.287 -0.009  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  1.298  0.015  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  1.289  0.183  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# ...

# %% [markdown]
# ### 线性回归衍生算法

# %% [markdown]
# #### Ridge(L2正则回归) 不带Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import Ridge

#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#模型开始训练
model = Ridge(alpha=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Ridge_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Ridge(L2正则回归) + Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import Ridge
from sklearn.preprocessing import StandardScaler

#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#对数据进行归一化
standard = StandardScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)

#模型开始训练
model = Ridge(alpha=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Ridge_With_Standard_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Lasso(L1正则回归)不带Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import Lasso

#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#模型开始训练
model = Lasso(alpha=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Lasso_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Lasso(L1正则回归) + Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler

#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#对数据进行归一化
standard = StandardScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)

#模型开始训练
model = Lasso(alpha=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Lasso_With_Z_score_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Elastic_Net弹性网络不带Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import ElasticNet
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#对数据进行归一化
standard = StandardScaler()
X_train = standard.fit_transform(X_train)
X_test = standard.fit_transform(X_test)

#模型开始训练
model = ElasticNet(alpha=0.1,l1_ratio=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Elastic_Net_With_Standard_result.txt',y_pred)
# Out:
#       V0     V1     V2     V3     V4     V5     V6     V7  ...    V30    V31    V32    V33    V34    V35    V36    V37
# 0  0.566  0.016 -0.143  0.407  0.452 -0.901 -1.812 -2.360  ...  0.109 -0.615  0.327 -4.627 -4.789 -5.101 -2.608 -3.508
# 1  0.968  0.437  0.066  0.566  0.194 -0.893 -1.566 -2.360  ...  0.124  0.032  0.600 -0.843  0.160  0.364 -0.335 -0.730
# 2  1.013  0.568  0.235  0.370  0.112 -0.797 -1.367 -2.360  ...  0.361  0.277 -0.116 -0.843  0.160  0.364  0.765 -0.589
# 3  0.733  0.368  0.283  0.165  0.599 -0.679 -1.200 -2.086  ...  0.417  0.279  0.603 -0.843 -0.065  0.364  0.333 -0.112
# 4  0.684  0.638  0.260  0.209  0.337 -0.454 -1.073 -2.086  ...  1.078  0.328  0.418 -0.843 -0.215  0.364 -0.280 -0.028
#
# [5 rows x 38 columns]
#    target
# 0   0.175
# 1   0.676
# 2   0.633
# 3   0.206
# 4   0.384
# ...

# %% [markdown]
# #### Elastic_Net弹性网络+ Z_score()归一化

# %%
import pandas as pd 
import numpy as np
from sklearn.linear_model import ElasticNet
from sklearn.preprocessing import StandardScaler
#训练数据得打开与存储
data_train = pd.read_csv('./zhengqi_train.txt',sep = '\t')
X_train = data_train.iloc[:,:-1]
y_train = data_train.iloc[:,-1:]
display(X_train.head(),y_train.head())

#测试数据的打开与保存
X_test = pd.read_csv('./zhengqi_test.txt','\t')

#模型开始训练
model = ElasticNet(alpha=0.1,l1_ratio=0.1)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
np.savetxt('linear__Elastic_Net_result.txt',y_pred)
